# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
import streamlit as st

# %%
coin1 =np.array([[1, 15, 41, 60, 59, 90, 72, 63, 52, 70, 100, 156],[1, 20, 30, 60, 49, 69, 49, 10, 90, 140, 300, 140]])

data1 =pd.DataFrame(coin1, index=["CoinA", "CoinB"]).T
data1.head()
# Out:
#    CoinA  CoinB
# 0      1      1
# 1     15     20
# 2     41     30
# 3     60     60
# 4     59     49

# %%
plot =sb.scatterplot(data=data1, palette="magma")
plt.show(plot)

# %%
st.title("Crypto-currency value")
coin =st.selectbox("choose the coin :", list(["coinA", "coinB"]))
date =st.slider("choose the month :", min_value=0, max_value=12, value=5, step=1)
tell =st.button("See Value")
# Out:
# 2021-06-04 10:54:02.933 WARNING root:
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/gitpod/.pyenv/versions/3.8.10/lib/python3.8/site-packages/ipykernel_launcher.py [ARGUMENTS]

# %%
pwd
# Out:
# '/workspace/Heroku'
